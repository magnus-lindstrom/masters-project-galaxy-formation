# %%
import os
from os.path import expanduser
home_dir = expanduser("~")
module_path = home_dir + '/modules/'
import sys
sys.path.append(module_path)
import time
import importlib
import random
import tensorflow as tf
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy import stats
import model_management

np.random.seed(999)
random.seed(999)
# Out:
# /opt/anaconda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
### General parameters
run_on_cpu = False
nEpochs = 1e3
batchSize = 1e4
total_set_size = 300000 # how many examples will be used for training+validation+testing
train_size = 270000
val_size = 10000
test_size = 10000
early_stopping_param = 5
input_features = ['Halo_mass', 'Halo_mass_peak', 'Concentration', 'Type', 'Scale_peak_mass', 'Scale_half_mass', 
                 'Scale_last_MajM']
output_features = ['Stellar_mass', 'SFR']
save_figs = 1
fig_dir = 'figures/'

### Network parameters
nLayers = 20
activationFunction = 'tanh'
neuronsPerLayer = 20
loss_function = 'mse' # 'mse', 'weighted_mse_1' 'mae'

data_dict = {'X_pos': 0, 'Y_pos': 1, 'Z_pos': 2, 'X_vel': 3, 'Y_vel': 4, 'Z_vel': 5, 'Halo_mass': 6, 
             'Stellar_mass': 7, 'SFR': 8, 'Intra_cluster_mass': 9, 'Halo_mass_peak': 10, 'Stellar_mass_obs': 11, 
             'SFR_obs': 12, 'Halo_radius': 13, 'Concentration': 14, 'Halo_spin': 15, 'Scale_peak_mass': 16, 
             'Scale_half_mass': 17, 'Scale_last_MajM': 18, 'Type': 19}
unit_dict = {'X_pos': '', 'Y_pos': '', 'Z_pos': '', 'X_vel': '', 'Y_vel': '', 
             'Z_vel': '', 'Halo_mass': 'log($M_{G}/M_{S}$)', 'Stellar_mass': 'log($M_{G}/M_{S}$)', 'SFR': '', 
             'Intra_cluster_mass': '', 'Halo_mass_peak': 'log($M_{G}/M_{S}$)', 
             'Stellar_mass_obs': '', 'SFR_obs': '', 'Halo_radius': '', 
             'Concentration': '', 'Halo_spin': '', 'Scale_peak_mass': 'a', 
             'Scale_half_mass': 'a', 'Scale_last_MajM': 'a', 'Type': ''}

# %%
if run_on_cpu:
    os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
### Set name ending with parameters for figures to be saved
param_string = 'nLayers_%d_nNeurons_%d_actFun_%s_lossFunc_%s_nTrainSamples_%d_nEpochs_%d_batchSize_%d' % (
    nLayers, neuronsPerLayer, activationFunction, loss_function, train_size, nEpochs, batchSize)
print(param_string)
# Out:
# nLayers_20_nNeurons_20_actFun_tanh_lossFunc_mse_nTrainSamples_270000_nEpochs_1000_batchSize_10000

# %% [markdown]
# # Load and preprocess the data

# %%
galfile = pd.read_hdf('/scratch/data/galcats/P200/galaxies.Z01.h5')
galaxies = galfile.as_matrix()
gal_header = galfile.keys().tolist()

### Remove data points with halo mass below 10.5
print(np.shape(galaxies))
galaxies = galaxies[galaxies[:,6] > 10.5, :]
print(np.shape(galaxies))
print(galaxies[:10,6])

halo_min_mass = np.min(galaxies[:, 6])
halo_max_mass = np.max(galaxies[:, 6])
# Out:
# (594946, 20)
# (306925, 20)
# [11.06128  10.74806  10.517851 11.935673 11.820144 11.564987 10.759135
#  10.828308 10.803138 10.55098 ]

# %%
n_data_points = galaxies.shape[0]
subset_indices = np.random.choice(n_data_points, total_set_size, replace=False)
train_indices = subset_indices[: int(train_size)]
val_indices = subset_indices[int(train_size) : int(train_size+val_size)]
test_indices = subset_indices[int(train_size+val_size) :]

x_train = np.zeros((len(train_indices), len(input_features)))
x_val = np.zeros((len(val_indices), len(input_features)))
x_test = np.zeros((len(test_indices), len(input_features)))
y_train = np.zeros((len(train_indices), len(output_features)))
y_val = np.zeros((len(val_indices), len(output_features)))
y_test = np.zeros((len(test_indices), len(output_features)))

for i in range(len(input_features)):
    x_train[:,i] = galaxies[train_indices, data_dict[input_features[i]]]
    x_val[:,i] = galaxies[val_indices, data_dict[input_features[i]]]
    x_test[:,i] = galaxies[test_indices, data_dict[input_features[i]]]
    
for i in range(len(output_features)):
    y_train[:,i] = galaxies[train_indices, data_dict[output_features[i]]]
    y_val[:,i] = galaxies[val_indices, data_dict[output_features[i]]]
    y_test[:,i] = galaxies[test_indices, data_dict[output_features[i]]]

# %%
### ZERO MEAN, UNIT STD

norm = 'zero_mean_unit_std_norm'

for i in range(np.size(x_train, 1)):
    x_data_means = np.mean(x_train, 0)
    x_data_stds = np.std(x_train, 0)

    x_train_norm = (x_train - x_data_means) / x_data_stds
    x_val_norm = (x_val - x_data_means) / x_data_stds
    x_test_norm = (x_test - x_data_means) / x_data_stds

for i in range(np.size(y_train, 1)):
    y_data_means = np.mean(y_train, 0)
    y_data_stds = np.std(y_train, 0)

    y_train_norm = (y_train - y_data_means) / y_data_stds
    y_val_norm = (y_val - y_data_means) / y_data_stds
    y_test_norm = (y_test - y_data_means) / y_data_stds

# %%
### BETWEEN ZERO AND ONE

norm = 'zero_to_one_norm'

for i in range(np.size(x_train, 1)):
    x_data_max = np.max(x_train, 0)
    x_data_min = np.min(x_train, 0)

    x_train_norm = (x_train - x_data_min) / (x_data_max - x_data_min)
    x_val_norm = (x_val - x_data_min) / (x_data_max - x_data_min)
    x_test_norm = (x_test - x_data_min) / (x_data_max - x_data_min)

for i in range(np.size(y_train, 1)):
    y_data_max = np.max(y_train, 0)
    y_data_min = np.min(y_train, 0)

    y_train_norm = (y_train - y_data_min) / (y_data_max - y_data_min)
    y_val_norm = (y_val - y_data_min) / (y_data_max - y_data_min)
    y_test_norm = (y_test - y_data_min) / (y_data_max - y_data_min)

# %%
print(np.mean(y_test_norm, 0))
print(np.std(y_test_norm, 0))
print(np.min(x_test_norm, 0))
print(np.max(x_test_norm, 0))
# Out:
# [-0.01316322  0.00215544]
# [0.9980486  1.10182612]
# [-1.22516374 -1.4079761  -0.61562333 -0.48765187 -3.99103739 -2.61115371
#  -1.27381868]
# [ 6.85216896  6.74985872 85.85107309  3.27358917  0.83450575  3.88992216
#   2.60675203]

# %%
### Get a feel for the data
for i in range(len(input_features)):
    print(input_features[i],': min: %.2e, max: %.2e.' % (np.min(x_train[:,i]), np.max(x_train[:,i])))
for i in range(len(output_features)):
    print(output_features[i],': min: %.2e, max: %.2e.' % (np.min(y_train[:,i]), np.max(y_train[:,i])))
# Out:
# Halo_mass : min: 1.05e+01, max: 1.52e+01.
# Halo_mass_peak : min: 1.05e+01, max: 1.52e+01.
# Concentration : min: 1.00e+00, max: 5.37e+03.
# Type : min: 0.00e+00, max: 2.00e+00.
# Scale_peak_mass : min: 1.00e-01, max: 9.10e-01.
# Scale_half_mass : min: 7.00e-02, max: 9.10e-01.
# Scale_last_MajM : min: 6.00e-02, max: 9.10e-01.
# Stellar_mass : min: 7.00e+00, max: 1.21e+01.
# SFR : min: 0.00e+00, max: 3.67e+01.

# %%
from keras import backend as K
def weighted_mse_1(y_true, y_pred):
    
    return K.mean(K.log(y_true+1.5) + K.square(y_pred - y_true), axis=-1)
loss_func_dict = {
    'mse': 'mse',
    'mae': 'mae',
    'weighted_mse_1': weighted_mse_1
}

# %%
### Visualisation for when we have 2 input features
# %matplotlib notebook
input_feat_1 = 0
input_feat_2 = 1
output_feat = 1

fig = plt.figure(1, figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_train_norm[:500,input_feat_1], x_train_norm[:500,input_feat_2], 
           y_train_norm[:500,output_feat])
ax.set_xlabel('%s log($M_{H}/M_{S}$)' % (input_features[input_feat_1]))
ax.set_ylabel('%s log($M_{H}/M_{S}$)' % (input_features[input_feat_2]))
ax.set_zlabel('%s log($M_{G}/M_{S}$)' % (output_features[output_feat]))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Load an existing model

# %%
### Search for the model that you want
importlib.reload(model_management)
search_dict = {
    'training_method': 'backprop'
}
[model_dicts, description_dicts] = model_management.SearchModel(search_dict, get_hits=True)
print(description_dicts)
print('\n')
for key in model_dicts:
    print(key)
    print(model_dicts[key])
    print('\n')

# %%
importlib.reload(model_management)
model, model_dict, description = model_management.LoadModel(search_dict, 1)

# %% [markdown]
# # Create a new model

# %%
# create model
model = Sequential()
model.add(Dense(neuronsPerLayer, input_dim = len(input_features), activation = activationFunction))

for i in range(0, nLayers-1): # -1 because one layer is added automatically with the input layer
    model.add(Dense(neuronsPerLayer, activation = activationFunction))

model.add(Dense(len(output_features), activation = 'relu'))

# Compile model
model.compile(loss=loss_func_dict[loss_function], metrics=['mse'], optimizer='adam')#, metrics=[loss_function])

# Fit the model
early_stopping = EarlyStopping(monitor='val_loss', patience=early_stopping_param)
history = model.fit(x_train_norm , y_train_norm, validation_data=(x_val_norm, y_val_norm), 
                    epochs=int(nEpochs), batch_size=int(batchSize))
# Out:
# Train on 270000 samples, validate on 10000 samples
# Epoch 1/1000
# 270000/270000 [==============================] - 2s 7us/step - loss: 0.7565 - mean_squared_error: 0.7565 - val_loss: 0.6416 - val_mean_squared_error: 0.6416
# Epoch 2/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.5878 - mean_squared_error: 0.5878 - val_loss: 0.5943 - val_mean_squared_error: 0.5943
# Epoch 3/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.5538 - mean_squared_error: 0.5538 - val_loss: 0.5641 - val_mean_squared_error: 0.5641
# Epoch 4/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.5325 - mean_squared_error: 0.5325 - val_loss: 0.5388 - val_mean_squared_error: 0.5388
# Epoch 5/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.5130 - mean_squared_error: 0.5130 - val_loss: 0.5143 - val_mean_squared_error: 0.5143
# Epoch 6/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4969 - mean_squared_error: 0.4969 - val_loss: 0.4957 - val_mean_squared_error: 0.4957
# Epoch 7/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4841 - mean_squared_error: 0.4841 - val_loss: 0.4820 - val_mean_squared_error: 0.4820
# Epoch 8/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4740 - mean_squared_error: 0.4740 - val_loss: 0.4758 - val_mean_squared_error: 0.4758
# Epoch 9/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4662 - mean_squared_error: 0.4662 - val_loss: 0.4661 - val_mean_squared_error: 0.4661
# Epoch 10/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4599 - mean_squared_error: 0.4599 - val_loss: 0.4588 - val_mean_squared_error: 0.4588
# Epoch 11/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4529 - mean_squared_error: 0.4529 - val_loss: 0.4501 - val_mean_squared_error: 0.4501
# Epoch 12/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4469 - mean_squared_error: 0.4469 - val_loss: 0.4431 - val_mean_squared_error: 0.4431
# Epoch 13/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4405 - mean_squared_error: 0.4405 - val_loss: 0.4357 - val_mean_squared_error: 0.4357
# Epoch 14/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4361 - mean_squared_error: 0.4361 - val_loss: 0.4307 - val_mean_squared_error: 0.4307
# Epoch 15/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4312 - mean_squared_error: 0.4312 - val_loss: 0.4262 - val_mean_squared_error: 0.4262
# Epoch 16/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4287 - mean_squared_error: 0.4287 - val_loss: 0.4300 - val_mean_squared_error: 0.4300
# Epoch 17/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4294 - mean_squared_error: 0.4294 - val_loss: 0.4196 - val_mean_squared_error: 0.4196
# Epoch 18/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4249 - mean_squared_error: 0.4249 - val_loss: 0.4223 - val_mean_squared_error: 0.4223
# Epoch 19/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.4251 - mean_squared_error: 0.4251 - val_loss: 0.4170 - val_mean_squared_error: 0.4170
# Epoch 20/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4228 - mean_squared_error: 0.4228 - val_loss: 0.4128 - val_mean_squared_error: 0.4128
# Epoch 21/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.4191 - mean_squared_error: 0.4191 - val_loss: 0.4131 - val_mean_squared_error: 0.4131
# Epoch 22/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4175 - mean_squared_error: 0.4175 - val_loss: 0.4129 - val_mean_squared_error: 0.4129
# Epoch 23/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4200 - mean_squared_error: 0.4200 - val_loss: 0.4128 - val_mean_squared_error: 0.4128
# Epoch 24/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4167 - mean_squared_error: 0.4167 - val_loss: 0.4123 - val_mean_squared_error: 0.4123
# Epoch 25/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4154 - mean_squared_error: 0.4154 - val_loss: 0.4126 - val_mean_squared_error: 0.4126
# Epoch 26/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4182 - mean_squared_error: 0.4182 - val_loss: 0.4067 - val_mean_squared_error: 0.4067
# Epoch 27/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4147 - mean_squared_error: 0.4147 - val_loss: 0.4210 - val_mean_squared_error: 0.4210
# Epoch 28/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4156 - mean_squared_error: 0.4156 - val_loss: 0.4073 - val_mean_squared_error: 0.4073
# Epoch 29/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4166 - mean_squared_error: 0.4166 - val_loss: 0.4068 - val_mean_squared_error: 0.4068
# Epoch 30/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4129 - mean_squared_error: 0.4129 - val_loss: 0.4066 - val_mean_squared_error: 0.4066
# Epoch 31/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4127 - mean_squared_error: 0.4127 - val_loss: 0.4053 - val_mean_squared_error: 0.4053
# Epoch 32/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.4097 - mean_squared_error: 0.4097 - val_loss: 0.4002 - val_mean_squared_error: 0.4002
# Epoch 33/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.4071 - mean_squared_error: 0.4071 - val_loss: 0.4013 - val_mean_squared_error: 0.4013
# Epoch 34/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4085 - mean_squared_error: 0.4085 - val_loss: 0.4009 - val_mean_squared_error: 0.4009
# Epoch 35/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4067 - mean_squared_error: 0.4067 - val_loss: 0.4042 - val_mean_squared_error: 0.4042
# Epoch 36/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4073 - mean_squared_error: 0.4073 - val_loss: 0.4065 - val_mean_squared_error: 0.4065
# Epoch 37/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4073 - mean_squared_error: 0.4073 - val_loss: 0.4027 - val_mean_squared_error: 0.4027
# Epoch 38/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4093 - mean_squared_error: 0.4093 - val_loss: 0.4002 - val_mean_squared_error: 0.4002
# Epoch 39/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4065 - mean_squared_error: 0.4065 - val_loss: 0.3981 - val_mean_squared_error: 0.3981
# Epoch 40/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4099 - mean_squared_error: 0.4099 - val_loss: 0.4025 - val_mean_squared_error: 0.4025
# Epoch 41/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.4063 - mean_squared_error: 0.4063 - val_loss: 0.4006 - val_mean_squared_error: 0.4006
# Epoch 42/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.4033 - mean_squared_error: 0.4033 - val_loss: 0.3963 - val_mean_squared_error: 0.3963
# Epoch 43/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4050 - mean_squared_error: 0.4050 - val_loss: 0.3972 - val_mean_squared_error: 0.3972
# Epoch 44/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4047 - mean_squared_error: 0.4047 - val_loss: 0.3976 - val_mean_squared_error: 0.3976
# Epoch 45/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4033 - mean_squared_error: 0.4033 - val_loss: 0.4038 - val_mean_squared_error: 0.4038
# Epoch 46/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.4018 - mean_squared_error: 0.4018 - val_loss: 0.3912 - val_mean_squared_error: 0.3912
# Epoch 47/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4020 - mean_squared_error: 0.4020 - val_loss: 0.4046 - val_mean_squared_error: 0.4046
# Epoch 48/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.4034 - mean_squared_error: 0.4034 - val_loss: 0.3918 - val_mean_squared_error: 0.3918
# Epoch 49/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4001 - mean_squared_error: 0.4001 - val_loss: 0.3990 - val_mean_squared_error: 0.3990
# Epoch 50/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4019 - mean_squared_error: 0.4019 - val_loss: 0.3920 - val_mean_squared_error: 0.3920
# Epoch 51/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3988 - mean_squared_error: 0.3988 - val_loss: 0.3951 - val_mean_squared_error: 0.3951
# Epoch 52/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3998 - mean_squared_error: 0.3998 - val_loss: 0.4017 - val_mean_squared_error: 0.4017
# Epoch 53/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4019 - mean_squared_error: 0.4019 - val_loss: 0.3956 - val_mean_squared_error: 0.3956
# Epoch 54/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3985 - mean_squared_error: 0.3985 - val_loss: 0.3922 - val_mean_squared_error: 0.3922
# Epoch 55/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4026 - mean_squared_error: 0.4026 - val_loss: 0.3970 - val_mean_squared_error: 0.3970
# Epoch 56/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3977 - mean_squared_error: 0.3977 - val_loss: 0.3930 - val_mean_squared_error: 0.3930
# Epoch 57/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3958 - mean_squared_error: 0.3958 - val_loss: 0.3886 - val_mean_squared_error: 0.3886
# Epoch 58/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3960 - mean_squared_error: 0.3960 - val_loss: 0.3924 - val_mean_squared_error: 0.3924
# Epoch 59/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3958 - mean_squared_error: 0.3958 - val_loss: 0.3915 - val_mean_squared_error: 0.3915
# Epoch 60/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.4002 - mean_squared_error: 0.4002 - val_loss: 0.3871 - val_mean_squared_error: 0.3871
# Epoch 61/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3985 - mean_squared_error: 0.3985 - val_loss: 0.3979 - val_mean_squared_error: 0.3979
# Epoch 62/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3978 - mean_squared_error: 0.3978 - val_loss: 0.3896 - val_mean_squared_error: 0.3896
# Epoch 63/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3950 - mean_squared_error: 0.3950 - val_loss: 0.3869 - val_mean_squared_error: 0.3869
# Epoch 64/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3929 - mean_squared_error: 0.3929 - val_loss: 0.3886 - val_mean_squared_error: 0.3886
# Epoch 65/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3944 - mean_squared_error: 0.3944 - val_loss: 0.3897 - val_mean_squared_error: 0.3897
# Epoch 66/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3958 - mean_squared_error: 0.3958 - val_loss: 0.3895 - val_mean_squared_error: 0.3895
# Epoch 67/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3954 - mean_squared_error: 0.3954 - val_loss: 0.3894 - val_mean_squared_error: 0.3894
# Epoch 68/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3924 - mean_squared_error: 0.3924 - val_loss: 0.3885 - val_mean_squared_error: 0.3885
# Epoch 69/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3943 - mean_squared_error: 0.3943 - val_loss: 0.3893 - val_mean_squared_error: 0.3893
# Epoch 70/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3950 - mean_squared_error: 0.3950 - val_loss: 0.3847 - val_mean_squared_error: 0.3847
# Epoch 71/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3952 - mean_squared_error: 0.3952 - val_loss: 0.3866 - val_mean_squared_error: 0.3866
# Epoch 72/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3948 - mean_squared_error: 0.3948 - val_loss: 0.3896 - val_mean_squared_error: 0.3896
# Epoch 73/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3941 - mean_squared_error: 0.3941 - val_loss: 0.3895 - val_mean_squared_error: 0.3895
# Epoch 74/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3934 - mean_squared_error: 0.3934 - val_loss: 0.3898 - val_mean_squared_error: 0.3898
# Epoch 75/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3922 - mean_squared_error: 0.3922 - val_loss: 0.3864 - val_mean_squared_error: 0.3864
# Epoch 76/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3927 - mean_squared_error: 0.3927 - val_loss: 0.3906 - val_mean_squared_error: 0.3906
# Epoch 77/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3935 - mean_squared_error: 0.3935 - val_loss: 0.3898 - val_mean_squared_error: 0.3898
# Epoch 78/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3939 - mean_squared_error: 0.3939 - val_loss: 0.3913 - val_mean_squared_error: 0.3913
# Epoch 79/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3926 - mean_squared_error: 0.3926 - val_loss: 0.3820 - val_mean_squared_error: 0.3820
# Epoch 80/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3897 - mean_squared_error: 0.3897 - val_loss: 0.3852 - val_mean_squared_error: 0.3852
# Epoch 81/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3913 - mean_squared_error: 0.3913 - val_loss: 0.3807 - val_mean_squared_error: 0.3807
# Epoch 82/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3920 - mean_squared_error: 0.3920 - val_loss: 0.3946 - val_mean_squared_error: 0.3946
# Epoch 83/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3911 - mean_squared_error: 0.3911 - val_loss: 0.3832 - val_mean_squared_error: 0.3832
# Epoch 84/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3922 - mean_squared_error: 0.3922 - val_loss: 0.3829 - val_mean_squared_error: 0.3829
# Epoch 85/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3934 - mean_squared_error: 0.3934 - val_loss: 0.3938 - val_mean_squared_error: 0.3938
# Epoch 86/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3901 - mean_squared_error: 0.3901 - val_loss: 0.3819 - val_mean_squared_error: 0.3819
# Epoch 87/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3914 - mean_squared_error: 0.3914 - val_loss: 0.3854 - val_mean_squared_error: 0.3854
# Epoch 88/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3875 - mean_squared_error: 0.3875 - val_loss: 0.3811 - val_mean_squared_error: 0.3811
# Epoch 89/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3872 - mean_squared_error: 0.3872 - val_loss: 0.3824 - val_mean_squared_error: 0.3824
# Epoch 90/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3887 - mean_squared_error: 0.3887 - val_loss: 0.3826 - val_mean_squared_error: 0.3826
# Epoch 91/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3888 - mean_squared_error: 0.3888 - val_loss: 0.3781 - val_mean_squared_error: 0.3781
# Epoch 92/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3879 - mean_squared_error: 0.3879 - val_loss: 0.3809 - val_mean_squared_error: 0.3809
# Epoch 93/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3865 - mean_squared_error: 0.3865 - val_loss: 0.3783 - val_mean_squared_error: 0.3783
# Epoch 94/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3877 - mean_squared_error: 0.3877 - val_loss: 0.3897 - val_mean_squared_error: 0.3897
# Epoch 95/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3909 - mean_squared_error: 0.3909 - val_loss: 0.3879 - val_mean_squared_error: 0.3879
# Epoch 96/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3862 - mean_squared_error: 0.3862 - val_loss: 0.3814 - val_mean_squared_error: 0.3814
# Epoch 97/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3855 - mean_squared_error: 0.3855 - val_loss: 0.3782 - val_mean_squared_error: 0.3782
# Epoch 98/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3860 - mean_squared_error: 0.3860 - val_loss: 0.3878 - val_mean_squared_error: 0.3878
# Epoch 99/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3869 - mean_squared_error: 0.3869 - val_loss: 0.3750 - val_mean_squared_error: 0.3750
# Epoch 100/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3891 - mean_squared_error: 0.3891 - val_loss: 0.3776 - val_mean_squared_error: 0.3776
# Epoch 101/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3880 - mean_squared_error: 0.3880 - val_loss: 0.3877 - val_mean_squared_error: 0.3877
# Epoch 102/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3892 - mean_squared_error: 0.3892 - val_loss: 0.3800 - val_mean_squared_error: 0.3800
# Epoch 103/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3894 - mean_squared_error: 0.3894 - val_loss: 0.3781 - val_mean_squared_error: 0.3781
# Epoch 104/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3899 - mean_squared_error: 0.3899 - val_loss: 0.3798 - val_mean_squared_error: 0.3798
# Epoch 105/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3869 - mean_squared_error: 0.3869 - val_loss: 0.3800 - val_mean_squared_error: 0.3800
# Epoch 106/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3836 - mean_squared_error: 0.3836 - val_loss: 0.3781 - val_mean_squared_error: 0.3781
# Epoch 107/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3855 - mean_squared_error: 0.3855 - val_loss: 0.3757 - val_mean_squared_error: 0.3757
# Epoch 108/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3847 - mean_squared_error: 0.3847 - val_loss: 0.3791 - val_mean_squared_error: 0.3791
# Epoch 109/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3846 - mean_squared_error: 0.3846 - val_loss: 0.3823 - val_mean_squared_error: 0.3823
# Epoch 110/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3836 - mean_squared_error: 0.3836 - val_loss: 0.3786 - val_mean_squared_error: 0.3786
# Epoch 111/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3870 - mean_squared_error: 0.3870 - val_loss: 0.3774 - val_mean_squared_error: 0.3774
# Epoch 112/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3843 - mean_squared_error: 0.3843 - val_loss: 0.3758 - val_mean_squared_error: 0.3758
# Epoch 113/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3842 - mean_squared_error: 0.3842 - val_loss: 0.3760 - val_mean_squared_error: 0.3760
# Epoch 114/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3825 - mean_squared_error: 0.3825 - val_loss: 0.3746 - val_mean_squared_error: 0.3746
# Epoch 115/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3841 - mean_squared_error: 0.3841 - val_loss: 0.3777 - val_mean_squared_error: 0.3777
# Epoch 116/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3840 - mean_squared_error: 0.3840 - val_loss: 0.3711 - val_mean_squared_error: 0.3711
# Epoch 117/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3893 - mean_squared_error: 0.3893 - val_loss: 0.3798 - val_mean_squared_error: 0.3798
# Epoch 118/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3828 - mean_squared_error: 0.3828 - val_loss: 0.3768 - val_mean_squared_error: 0.3768
# Epoch 119/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3813 - mean_squared_error: 0.3813 - val_loss: 0.3743 - val_mean_squared_error: 0.3743
# Epoch 120/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3815 - mean_squared_error: 0.3815 - val_loss: 0.3746 - val_mean_squared_error: 0.3746
# Epoch 121/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3852 - mean_squared_error: 0.3852 - val_loss: 0.3764 - val_mean_squared_error: 0.3764
# Epoch 122/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3817 - mean_squared_error: 0.3817 - val_loss: 0.3756 - val_mean_squared_error: 0.3756
# Epoch 123/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3813 - mean_squared_error: 0.3813 - val_loss: 0.3743 - val_mean_squared_error: 0.3743
# Epoch 124/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3807 - mean_squared_error: 0.3807 - val_loss: 0.3777 - val_mean_squared_error: 0.3777
# Epoch 125/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3801 - mean_squared_error: 0.3801 - val_loss: 0.3728 - val_mean_squared_error: 0.3728
# Epoch 126/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3808 - mean_squared_error: 0.3808 - val_loss: 0.3811 - val_mean_squared_error: 0.3811
# Epoch 127/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3856 - mean_squared_error: 0.3856 - val_loss: 0.3759 - val_mean_squared_error: 0.3759
# Epoch 128/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3843 - mean_squared_error: 0.3843 - val_loss: 0.3793 - val_mean_squared_error: 0.3793
# Epoch 129/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3835 - mean_squared_error: 0.3835 - val_loss: 0.3768 - val_mean_squared_error: 0.3768
# Epoch 130/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3823 - mean_squared_error: 0.3823 - val_loss: 0.3759 - val_mean_squared_error: 0.3759
# Epoch 131/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3804 - mean_squared_error: 0.3804 - val_loss: 0.3679 - val_mean_squared_error: 0.3679
# Epoch 132/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3790 - mean_squared_error: 0.3790 - val_loss: 0.3774 - val_mean_squared_error: 0.3774
# Epoch 133/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3829 - mean_squared_error: 0.3829 - val_loss: 0.3815 - val_mean_squared_error: 0.3815
# Epoch 134/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3848 - mean_squared_error: 0.3848 - val_loss: 0.3746 - val_mean_squared_error: 0.3746
# Epoch 135/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3801 - mean_squared_error: 0.3801 - val_loss: 0.3745 - val_mean_squared_error: 0.3745
# Epoch 136/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3788 - mean_squared_error: 0.3788 - val_loss: 0.3698 - val_mean_squared_error: 0.3698
# Epoch 137/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3793 - mean_squared_error: 0.3793 - val_loss: 0.3712 - val_mean_squared_error: 0.3712
# Epoch 138/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3802 - mean_squared_error: 0.3802 - val_loss: 0.3775 - val_mean_squared_error: 0.3775
# Epoch 139/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3814 - mean_squared_error: 0.3814 - val_loss: 0.3750 - val_mean_squared_error: 0.3750
# Epoch 140/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3805 - mean_squared_error: 0.3805 - val_loss: 0.3761 - val_mean_squared_error: 0.3761
# Epoch 141/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3852 - mean_squared_error: 0.3852 - val_loss: 0.3787 - val_mean_squared_error: 0.3787
# Epoch 142/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3838 - mean_squared_error: 0.3838 - val_loss: 0.3838 - val_mean_squared_error: 0.3838
# Epoch 143/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3793 - mean_squared_error: 0.3793 - val_loss: 0.3723 - val_mean_squared_error: 0.3723
# Epoch 144/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3761 - mean_squared_error: 0.3761 - val_loss: 0.3692 - val_mean_squared_error: 0.3692
# Epoch 145/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3773 - mean_squared_error: 0.3773 - val_loss: 0.3676 - val_mean_squared_error: 0.3676
# Epoch 146/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3829 - mean_squared_error: 0.3829 - val_loss: 0.3787 - val_mean_squared_error: 0.3787
# Epoch 147/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3772 - mean_squared_error: 0.3772 - val_loss: 0.3682 - val_mean_squared_error: 0.3682
# Epoch 148/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3784 - mean_squared_error: 0.3784 - val_loss: 0.3708 - val_mean_squared_error: 0.3708
# Epoch 149/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3776 - mean_squared_error: 0.3776 - val_loss: 0.3709 - val_mean_squared_error: 0.3709
# Epoch 150/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3813 - mean_squared_error: 0.3813 - val_loss: 0.3713 - val_mean_squared_error: 0.3713
# Epoch 151/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3809 - mean_squared_error: 0.3809 - val_loss: 0.3759 - val_mean_squared_error: 0.3759
# Epoch 152/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3752 - mean_squared_error: 0.3752 - val_loss: 0.3729 - val_mean_squared_error: 0.3729
# Epoch 153/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3761 - mean_squared_error: 0.3761 - val_loss: 0.3669 - val_mean_squared_error: 0.3669
# Epoch 154/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3781 - mean_squared_error: 0.3781 - val_loss: 0.3745 - val_mean_squared_error: 0.3745
# Epoch 155/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3752 - mean_squared_error: 0.3752 - val_loss: 0.3672 - val_mean_squared_error: 0.3672
# Epoch 156/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3746 - mean_squared_error: 0.3746 - val_loss: 0.3781 - val_mean_squared_error: 0.3781
# Epoch 157/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3761 - mean_squared_error: 0.3761 - val_loss: 0.3677 - val_mean_squared_error: 0.3677
# Epoch 158/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3754 - mean_squared_error: 0.3754 - val_loss: 0.3723 - val_mean_squared_error: 0.3723
# Epoch 159/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3759 - mean_squared_error: 0.3759 - val_loss: 0.3705 - val_mean_squared_error: 0.3705
# Epoch 160/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3752 - mean_squared_error: 0.3752 - val_loss: 0.3756 - val_mean_squared_error: 0.3756
# Epoch 161/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3801 - mean_squared_error: 0.3801 - val_loss: 0.3868 - val_mean_squared_error: 0.3868
# Epoch 162/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3766 - mean_squared_error: 0.3766 - val_loss: 0.3693 - val_mean_squared_error: 0.3693
# Epoch 163/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3736 - mean_squared_error: 0.3736 - val_loss: 0.3673 - val_mean_squared_error: 0.3673
# Epoch 164/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3769 - mean_squared_error: 0.3769 - val_loss: 0.3704 - val_mean_squared_error: 0.3704
# Epoch 165/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3784 - mean_squared_error: 0.3784 - val_loss: 0.3681 - val_mean_squared_error: 0.3681
# Epoch 166/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3760 - mean_squared_error: 0.3760 - val_loss: 0.3691 - val_mean_squared_error: 0.3691
# Epoch 167/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3753 - mean_squared_error: 0.3753 - val_loss: 0.3669 - val_mean_squared_error: 0.3669
# Epoch 168/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3767 - mean_squared_error: 0.3767 - val_loss: 0.3736 - val_mean_squared_error: 0.3736
# Epoch 169/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3759 - mean_squared_error: 0.3759 - val_loss: 0.3721 - val_mean_squared_error: 0.3721
# Epoch 170/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3757 - mean_squared_error: 0.3757 - val_loss: 0.3744 - val_mean_squared_error: 0.3744
# Epoch 171/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3744 - mean_squared_error: 0.3744 - val_loss: 0.3663 - val_mean_squared_error: 0.3663
# Epoch 172/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3711 - mean_squared_error: 0.3711 - val_loss: 0.3676 - val_mean_squared_error: 0.3676
# Epoch 173/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3720 - mean_squared_error: 0.3720 - val_loss: 0.3640 - val_mean_squared_error: 0.3640
# Epoch 174/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3719 - mean_squared_error: 0.3719 - val_loss: 0.3643 - val_mean_squared_error: 0.3643
# Epoch 175/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3760 - mean_squared_error: 0.3760 - val_loss: 0.3725 - val_mean_squared_error: 0.3725
# Epoch 176/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3725 - mean_squared_error: 0.3725 - val_loss: 0.3731 - val_mean_squared_error: 0.3731
# Epoch 177/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3775 - mean_squared_error: 0.3775 - val_loss: 0.3684 - val_mean_squared_error: 0.3684
# Epoch 178/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3762 - mean_squared_error: 0.3762 - val_loss: 0.3797 - val_mean_squared_error: 0.3797
# Epoch 179/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3778 - mean_squared_error: 0.3778 - val_loss: 0.3811 - val_mean_squared_error: 0.3811
# Epoch 180/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3778 - mean_squared_error: 0.3778 - val_loss: 0.3761 - val_mean_squared_error: 0.3761
# Epoch 181/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3750 - mean_squared_error: 0.3750 - val_loss: 0.3698 - val_mean_squared_error: 0.3698
# Epoch 182/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3744 - mean_squared_error: 0.3744 - val_loss: 0.3701 - val_mean_squared_error: 0.3701
# Epoch 183/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3796 - mean_squared_error: 0.3796 - val_loss: 0.3682 - val_mean_squared_error: 0.3682
# Epoch 184/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3763 - mean_squared_error: 0.3763 - val_loss: 0.3682 - val_mean_squared_error: 0.3682
# Epoch 185/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3756 - mean_squared_error: 0.3756 - val_loss: 0.3661 - val_mean_squared_error: 0.3661
# Epoch 186/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3810 - mean_squared_error: 0.3810 - val_loss: 0.3743 - val_mean_squared_error: 0.3743
# Epoch 187/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3770 - mean_squared_error: 0.3770 - val_loss: 0.3622 - val_mean_squared_error: 0.3622
# Epoch 188/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3797 - mean_squared_error: 0.3797 - val_loss: 0.3701 - val_mean_squared_error: 0.3701
# Epoch 189/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3848 - mean_squared_error: 0.3848 - val_loss: 0.3763 - val_mean_squared_error: 0.3763
# Epoch 190/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3718 - mean_squared_error: 0.3718 - val_loss: 0.3596 - val_mean_squared_error: 0.3596
# Epoch 191/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3716 - mean_squared_error: 0.3716 - val_loss: 0.3598 - val_mean_squared_error: 0.3598
# Epoch 192/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3705 - mean_squared_error: 0.3705 - val_loss: 0.3680 - val_mean_squared_error: 0.3680
# Epoch 193/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3715 - mean_squared_error: 0.3715 - val_loss: 0.3625 - val_mean_squared_error: 0.3625
# Epoch 194/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3690 - mean_squared_error: 0.3690 - val_loss: 0.3659 - val_mean_squared_error: 0.3659
# Epoch 195/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3691 - mean_squared_error: 0.3691 - val_loss: 0.3685 - val_mean_squared_error: 0.3685
# Epoch 196/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3741 - mean_squared_error: 0.3741 - val_loss: 0.3622 - val_mean_squared_error: 0.3622
# Epoch 197/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3738 - mean_squared_error: 0.3738 - val_loss: 0.3626 - val_mean_squared_error: 0.3626
# Epoch 198/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3731 - mean_squared_error: 0.3731 - val_loss: 0.3629 - val_mean_squared_error: 0.3629
# Epoch 199/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3737 - mean_squared_error: 0.3737 - val_loss: 0.3700 - val_mean_squared_error: 0.3700
# Epoch 200/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3731 - mean_squared_error: 0.3731 - val_loss: 0.3656 - val_mean_squared_error: 0.3656
# Epoch 201/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3701 - mean_squared_error: 0.3701 - val_loss: 0.3627 - val_mean_squared_error: 0.3627
# Epoch 202/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3697 - mean_squared_error: 0.3697 - val_loss: 0.3691 - val_mean_squared_error: 0.3691
# Epoch 203/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3733 - mean_squared_error: 0.3733 - val_loss: 0.3649 - val_mean_squared_error: 0.3649
# Epoch 204/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3697 - mean_squared_error: 0.3697 - val_loss: 0.3665 - val_mean_squared_error: 0.3665
# Epoch 205/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3682 - mean_squared_error: 0.3682 - val_loss: 0.3635 - val_mean_squared_error: 0.3635
# Epoch 206/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3688 - mean_squared_error: 0.3688 - val_loss: 0.3641 - val_mean_squared_error: 0.3641
# Epoch 207/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3693 - mean_squared_error: 0.3693 - val_loss: 0.3713 - val_mean_squared_error: 0.3713
# Epoch 208/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3708 - mean_squared_error: 0.3708 - val_loss: 0.3693 - val_mean_squared_error: 0.3693
# Epoch 209/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3676 - mean_squared_error: 0.3676 - val_loss: 0.3622 - val_mean_squared_error: 0.3622
# Epoch 210/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3689 - mean_squared_error: 0.3689 - val_loss: 0.3589 - val_mean_squared_error: 0.3589
# Epoch 211/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3749 - mean_squared_error: 0.3749 - val_loss: 0.3725 - val_mean_squared_error: 0.3725
# Epoch 212/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3741 - mean_squared_error: 0.3741 - val_loss: 0.3679 - val_mean_squared_error: 0.3679
# Epoch 213/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3684 - mean_squared_error: 0.3684 - val_loss: 0.3623 - val_mean_squared_error: 0.3623
# Epoch 214/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3716 - mean_squared_error: 0.3716 - val_loss: 0.3711 - val_mean_squared_error: 0.3711
# Epoch 215/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3697 - mean_squared_error: 0.3697 - val_loss: 0.3631 - val_mean_squared_error: 0.3631
# Epoch 216/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3655 - mean_squared_error: 0.3655 - val_loss: 0.3676 - val_mean_squared_error: 0.3676
# Epoch 217/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3697 - mean_squared_error: 0.3697 - val_loss: 0.3680 - val_mean_squared_error: 0.3680
# Epoch 218/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3773 - mean_squared_error: 0.3773 - val_loss: 0.3630 - val_mean_squared_error: 0.3630
# Epoch 219/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3738 - mean_squared_error: 0.3738 - val_loss: 0.3660 - val_mean_squared_error: 0.3660
# Epoch 220/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3668 - mean_squared_error: 0.3668 - val_loss: 0.3726 - val_mean_squared_error: 0.3726
# Epoch 221/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3728 - mean_squared_error: 0.3728 - val_loss: 0.3710 - val_mean_squared_error: 0.3710
# Epoch 222/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3774 - mean_squared_error: 0.3774 - val_loss: 0.3670 - val_mean_squared_error: 0.3670
# Epoch 223/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3730 - mean_squared_error: 0.3730 - val_loss: 0.3660 - val_mean_squared_error: 0.3660
# Epoch 224/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3726 - mean_squared_error: 0.3726 - val_loss: 0.3617 - val_mean_squared_error: 0.3617
# Epoch 225/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3701 - mean_squared_error: 0.3701 - val_loss: 0.3659 - val_mean_squared_error: 0.3659
# Epoch 226/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3704 - mean_squared_error: 0.3704 - val_loss: 0.3707 - val_mean_squared_error: 0.3707
# Epoch 227/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3680 - mean_squared_error: 0.3680 - val_loss: 0.3604 - val_mean_squared_error: 0.3604
# Epoch 228/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3693 - mean_squared_error: 0.3693 - val_loss: 0.3640 - val_mean_squared_error: 0.3640
# Epoch 229/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3664 - mean_squared_error: 0.3664 - val_loss: 0.3595 - val_mean_squared_error: 0.3595
# Epoch 230/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3655 - mean_squared_error: 0.3655 - val_loss: 0.3550 - val_mean_squared_error: 0.3550
# Epoch 231/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3668 - mean_squared_error: 0.3668 - val_loss: 0.3574 - val_mean_squared_error: 0.3574
# Epoch 232/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3661 - mean_squared_error: 0.3661 - val_loss: 0.3627 - val_mean_squared_error: 0.3627
# Epoch 233/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3644 - mean_squared_error: 0.3644 - val_loss: 0.3569 - val_mean_squared_error: 0.3569
# Epoch 234/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3708 - mean_squared_error: 0.3708 - val_loss: 0.3692 - val_mean_squared_error: 0.3692
# Epoch 235/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3700 - mean_squared_error: 0.3700 - val_loss: 0.3642 - val_mean_squared_error: 0.3642
# Epoch 236/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3655 - mean_squared_error: 0.3655 - val_loss: 0.3604 - val_mean_squared_error: 0.3604
# Epoch 237/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3682 - mean_squared_error: 0.3682 - val_loss: 0.3680 - val_mean_squared_error: 0.3680
# Epoch 238/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3679 - mean_squared_error: 0.3679 - val_loss: 0.3664 - val_mean_squared_error: 0.3664
# Epoch 239/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3664 - mean_squared_error: 0.3664 - val_loss: 0.3604 - val_mean_squared_error: 0.3604
# Epoch 240/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3694 - mean_squared_error: 0.3694 - val_loss: 0.3630 - val_mean_squared_error: 0.3630
# Epoch 241/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3679 - mean_squared_error: 0.3679 - val_loss: 0.3646 - val_mean_squared_error: 0.3646
# Epoch 242/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3650 - mean_squared_error: 0.3650 - val_loss: 0.3610 - val_mean_squared_error: 0.3610
# Epoch 243/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3664 - mean_squared_error: 0.3664 - val_loss: 0.3598 - val_mean_squared_error: 0.3598
# Epoch 244/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3624 - mean_squared_error: 0.3624 - val_loss: 0.3596 - val_mean_squared_error: 0.3596
# Epoch 245/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3659 - mean_squared_error: 0.3659 - val_loss: 0.3654 - val_mean_squared_error: 0.3654
# Epoch 246/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3674 - mean_squared_error: 0.3674 - val_loss: 0.3612 - val_mean_squared_error: 0.3612
# Epoch 247/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3628 - mean_squared_error: 0.3628 - val_loss: 0.3626 - val_mean_squared_error: 0.3626
# Epoch 248/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3657 - mean_squared_error: 0.3657 - val_loss: 0.3641 - val_mean_squared_error: 0.3641
# Epoch 249/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3718 - mean_squared_error: 0.3718 - val_loss: 0.3614 - val_mean_squared_error: 0.3614
# Epoch 250/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3618 - mean_squared_error: 0.3618 - val_loss: 0.3577 - val_mean_squared_error: 0.3577
# Epoch 251/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3644 - mean_squared_error: 0.3644 - val_loss: 0.3599 - val_mean_squared_error: 0.3599
# Epoch 252/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3642 - mean_squared_error: 0.3642 - val_loss: 0.3565 - val_mean_squared_error: 0.3565
# Epoch 253/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3614 - mean_squared_error: 0.3614 - val_loss: 0.3574 - val_mean_squared_error: 0.3574
# Epoch 254/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3661 - mean_squared_error: 0.3661 - val_loss: 0.3599 - val_mean_squared_error: 0.3599
# Epoch 255/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3638 - mean_squared_error: 0.3638 - val_loss: 0.3696 - val_mean_squared_error: 0.3696
# Epoch 256/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3636 - mean_squared_error: 0.3636 - val_loss: 0.3695 - val_mean_squared_error: 0.3695
# Epoch 257/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3652 - mean_squared_error: 0.3652 - val_loss: 0.3606 - val_mean_squared_error: 0.3606
# Epoch 258/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3637 - mean_squared_error: 0.3637 - val_loss: 0.3577 - val_mean_squared_error: 0.3577
# Epoch 259/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3620 - mean_squared_error: 0.3620 - val_loss: 0.3552 - val_mean_squared_error: 0.3552
# Epoch 260/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3752 - mean_squared_error: 0.3752 - val_loss: 0.3697 - val_mean_squared_error: 0.3697
# Epoch 261/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3663 - mean_squared_error: 0.3663 - val_loss: 0.3633 - val_mean_squared_error: 0.3633
# Epoch 262/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3673 - mean_squared_error: 0.3673 - val_loss: 0.3702 - val_mean_squared_error: 0.3702
# Epoch 263/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3663 - mean_squared_error: 0.3663 - val_loss: 0.3641 - val_mean_squared_error: 0.3641
# Epoch 264/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3769 - mean_squared_error: 0.3769 - val_loss: 0.3570 - val_mean_squared_error: 0.3570
# Epoch 265/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3639 - mean_squared_error: 0.3639 - val_loss: 0.3664 - val_mean_squared_error: 0.3664
# Epoch 266/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3637 - mean_squared_error: 0.3637 - val_loss: 0.3679 - val_mean_squared_error: 0.3679
# Epoch 267/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3725 - mean_squared_error: 0.3725 - val_loss: 0.3641 - val_mean_squared_error: 0.3641
# Epoch 268/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3646 - mean_squared_error: 0.3646 - val_loss: 0.3572 - val_mean_squared_error: 0.3572
# Epoch 269/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3677 - mean_squared_error: 0.3677 - val_loss: 0.3733 - val_mean_squared_error: 0.3733
# Epoch 270/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3684 - mean_squared_error: 0.3684 - val_loss: 0.3593 - val_mean_squared_error: 0.3593
# Epoch 271/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3625 - mean_squared_error: 0.3625 - val_loss: 0.3619 - val_mean_squared_error: 0.3619
# Epoch 272/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3611 - mean_squared_error: 0.3611 - val_loss: 0.3605 - val_mean_squared_error: 0.3605
# Epoch 273/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3597 - mean_squared_error: 0.3597 - val_loss: 0.3588 - val_mean_squared_error: 0.3588
# Epoch 274/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3636 - mean_squared_error: 0.3636 - val_loss: 0.3559 - val_mean_squared_error: 0.3559
# Epoch 275/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3632 - mean_squared_error: 0.3632 - val_loss: 0.3624 - val_mean_squared_error: 0.3624
# Epoch 276/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3673 - mean_squared_error: 0.3673 - val_loss: 0.3590 - val_mean_squared_error: 0.3590
# Epoch 277/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3613 - mean_squared_error: 0.3613 - val_loss: 0.3630 - val_mean_squared_error: 0.3630
# Epoch 278/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3634 - mean_squared_error: 0.3634 - val_loss: 0.3560 - val_mean_squared_error: 0.3560
# Epoch 279/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3579 - mean_squared_error: 0.3579 - val_loss: 0.3550 - val_mean_squared_error: 0.3550
# Epoch 280/1000
# ...
# Epoch 908/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3273 - mean_squared_error: 0.3273 - val_loss: 0.3922 - val_mean_squared_error: 0.3922
# Epoch 909/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3203 - mean_squared_error: 0.3203 - val_loss: 0.3593 - val_mean_squared_error: 0.3593
# Epoch 910/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3181 - mean_squared_error: 0.3181 - val_loss: 0.3736 - val_mean_squared_error: 0.3736
# Epoch 911/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3170 - mean_squared_error: 0.3170 - val_loss: 0.3536 - val_mean_squared_error: 0.3536
# Epoch 912/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3162 - mean_squared_error: 0.3162 - val_loss: 0.3827 - val_mean_squared_error: 0.3827
# Epoch 913/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3202 - mean_squared_error: 0.3202 - val_loss: 0.3774 - val_mean_squared_error: 0.3774
# Epoch 914/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3179 - mean_squared_error: 0.3179 - val_loss: 0.3552 - val_mean_squared_error: 0.3552
# Epoch 915/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3232 - mean_squared_error: 0.3232 - val_loss: 0.3579 - val_mean_squared_error: 0.3579
# Epoch 916/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3188 - mean_squared_error: 0.3188 - val_loss: 0.3622 - val_mean_squared_error: 0.3622
# Epoch 917/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3195 - mean_squared_error: 0.3195 - val_loss: 0.3801 - val_mean_squared_error: 0.3801
# Epoch 918/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3199 - mean_squared_error: 0.3199 - val_loss: 0.3673 - val_mean_squared_error: 0.3673
# Epoch 919/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3179 - mean_squared_error: 0.3179 - val_loss: 0.3430 - val_mean_squared_error: 0.3430
# Epoch 920/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3179 - mean_squared_error: 0.3179 - val_loss: 0.3453 - val_mean_squared_error: 0.3453
# Epoch 921/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3167 - mean_squared_error: 0.3167 - val_loss: 0.3494 - val_mean_squared_error: 0.3494
# Epoch 922/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3175 - mean_squared_error: 0.3175 - val_loss: 0.3500 - val_mean_squared_error: 0.3500
# Epoch 923/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3169 - mean_squared_error: 0.3169 - val_loss: 0.3377 - val_mean_squared_error: 0.3377
# Epoch 924/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3158 - mean_squared_error: 0.3158 - val_loss: 0.3510 - val_mean_squared_error: 0.3510
# Epoch 925/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3143 - mean_squared_error: 0.3143 - val_loss: 0.3763 - val_mean_squared_error: 0.3763
# Epoch 926/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3149 - mean_squared_error: 0.3149 - val_loss: 0.3462 - val_mean_squared_error: 0.3462
# Epoch 927/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3546 - mean_squared_error: 0.3546 - val_loss: 0.3491 - val_mean_squared_error: 0.3491
# Epoch 928/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3436 - mean_squared_error: 0.3436 - val_loss: 0.3447 - val_mean_squared_error: 0.3447
# Epoch 929/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3568 - mean_squared_error: 0.3568 - val_loss: 0.3648 - val_mean_squared_error: 0.3648
# Epoch 930/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3794 - mean_squared_error: 0.3794 - val_loss: 0.3483 - val_mean_squared_error: 0.3483
# Epoch 931/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3548 - mean_squared_error: 0.3548 - val_loss: 0.3575 - val_mean_squared_error: 0.3575
# Epoch 932/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3403 - mean_squared_error: 0.3403 - val_loss: 0.3873 - val_mean_squared_error: 0.3873
# Epoch 933/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3414 - mean_squared_error: 0.3414 - val_loss: 0.3732 - val_mean_squared_error: 0.3732
# Epoch 934/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3369 - mean_squared_error: 0.3369 - val_loss: 0.3864 - val_mean_squared_error: 0.3864
# Epoch 935/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3329 - mean_squared_error: 0.3329 - val_loss: 0.3660 - val_mean_squared_error: 0.3660
# Epoch 936/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3278 - mean_squared_error: 0.3278 - val_loss: 0.3782 - val_mean_squared_error: 0.3782
# Epoch 937/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3198 - mean_squared_error: 0.3198 - val_loss: 0.3653 - val_mean_squared_error: 0.3653
# Epoch 938/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3188 - mean_squared_error: 0.3188 - val_loss: 0.3661 - val_mean_squared_error: 0.3661
# Epoch 939/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3179 - mean_squared_error: 0.3179 - val_loss: 0.3608 - val_mean_squared_error: 0.3608
# Epoch 940/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3186 - mean_squared_error: 0.3186 - val_loss: 0.4040 - val_mean_squared_error: 0.4040
# Epoch 941/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3191 - mean_squared_error: 0.3191 - val_loss: 0.3613 - val_mean_squared_error: 0.3613
# Epoch 942/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3164 - mean_squared_error: 0.3164 - val_loss: 0.3595 - val_mean_squared_error: 0.3595
# Epoch 943/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3161 - mean_squared_error: 0.3161 - val_loss: 0.3671 - val_mean_squared_error: 0.3671
# Epoch 944/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3156 - mean_squared_error: 0.3156 - val_loss: 0.3730 - val_mean_squared_error: 0.3730
# Epoch 945/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3159 - mean_squared_error: 0.3159 - val_loss: 0.3808 - val_mean_squared_error: 0.3808
# Epoch 946/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3189 - mean_squared_error: 0.3189 - val_loss: 0.3651 - val_mean_squared_error: 0.3651
# Epoch 947/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3192 - mean_squared_error: 0.3192 - val_loss: 0.3957 - val_mean_squared_error: 0.3957
# Epoch 948/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3184 - mean_squared_error: 0.3184 - val_loss: 0.3542 - val_mean_squared_error: 0.3542
# Epoch 949/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3156 - mean_squared_error: 0.3156 - val_loss: 0.3593 - val_mean_squared_error: 0.3593
# Epoch 950/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3218 - mean_squared_error: 0.3218 - val_loss: 0.3527 - val_mean_squared_error: 0.3527
# Epoch 951/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3189 - mean_squared_error: 0.3189 - val_loss: 0.3689 - val_mean_squared_error: 0.3689
# Epoch 952/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3174 - mean_squared_error: 0.3174 - val_loss: 0.3420 - val_mean_squared_error: 0.3420
# Epoch 953/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3180 - mean_squared_error: 0.3180 - val_loss: 0.3474 - val_mean_squared_error: 0.3474
# Epoch 954/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3170 - mean_squared_error: 0.3170 - val_loss: 0.3764 - val_mean_squared_error: 0.3764
# Epoch 955/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3218 - mean_squared_error: 0.3218 - val_loss: 0.3455 - val_mean_squared_error: 0.3455
# Epoch 956/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3281 - mean_squared_error: 0.3281 - val_loss: 0.3912 - val_mean_squared_error: 0.3912
# Epoch 957/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3230 - mean_squared_error: 0.3230 - val_loss: 0.3598 - val_mean_squared_error: 0.3598
# Epoch 958/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3187 - mean_squared_error: 0.3187 - val_loss: 0.3899 - val_mean_squared_error: 0.3899
# Epoch 959/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3183 - mean_squared_error: 0.3183 - val_loss: 0.3737 - val_mean_squared_error: 0.3737
# Epoch 960/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3166 - mean_squared_error: 0.3166 - val_loss: 0.3555 - val_mean_squared_error: 0.3555
# Epoch 961/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3152 - mean_squared_error: 0.3152 - val_loss: 0.3653 - val_mean_squared_error: 0.3653
# Epoch 962/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3152 - mean_squared_error: 0.3152 - val_loss: 0.3417 - val_mean_squared_error: 0.3417
# Epoch 963/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3166 - mean_squared_error: 0.3166 - val_loss: 0.3308 - val_mean_squared_error: 0.3308
# Epoch 964/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3154 - mean_squared_error: 0.3154 - val_loss: 0.3453 - val_mean_squared_error: 0.3453
# Epoch 965/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3174 - mean_squared_error: 0.3174 - val_loss: 0.3472 - val_mean_squared_error: 0.3472
# Epoch 966/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3170 - mean_squared_error: 0.3170 - val_loss: 0.3493 - val_mean_squared_error: 0.3493
# Epoch 967/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3225 - mean_squared_error: 0.3225 - val_loss: 0.3644 - val_mean_squared_error: 0.3644
# Epoch 968/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3192 - mean_squared_error: 0.3192 - val_loss: 0.3543 - val_mean_squared_error: 0.3543
# Epoch 969/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3214 - mean_squared_error: 0.3214 - val_loss: 0.3732 - val_mean_squared_error: 0.3732
# Epoch 970/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3211 - mean_squared_error: 0.3211 - val_loss: 0.3382 - val_mean_squared_error: 0.3382
# Epoch 971/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3195 - mean_squared_error: 0.3195 - val_loss: 0.3336 - val_mean_squared_error: 0.3336
# Epoch 972/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3245 - mean_squared_error: 0.3245 - val_loss: 0.3840 - val_mean_squared_error: 0.3840
# Epoch 973/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3193 - mean_squared_error: 0.3193 - val_loss: 0.4013 - val_mean_squared_error: 0.4013
# Epoch 974/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3161 - mean_squared_error: 0.3161 - val_loss: 0.3462 - val_mean_squared_error: 0.3462
# Epoch 975/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3173 - mean_squared_error: 0.3173 - val_loss: 0.3613 - val_mean_squared_error: 0.3613
# Epoch 976/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3231 - mean_squared_error: 0.3231 - val_loss: 0.3925 - val_mean_squared_error: 0.3925
# Epoch 977/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3182 - mean_squared_error: 0.3182 - val_loss: 0.3421 - val_mean_squared_error: 0.3421
# Epoch 978/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3469 - mean_squared_error: 0.3469 - val_loss: 0.3596 - val_mean_squared_error: 0.3596
# Epoch 979/1000
# 270000/270000 [==============================] - 1s 2us/step - loss: 0.3462 - mean_squared_error: 0.3462 - val_loss: 0.3515 - val_mean_squared_error: 0.3515
# Epoch 980/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3400 - mean_squared_error: 0.3400 - val_loss: 0.3394 - val_mean_squared_error: 0.3394
# Epoch 981/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3315 - mean_squared_error: 0.3315 - val_loss: 0.3865 - val_mean_squared_error: 0.3865
# Epoch 982/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3192 - mean_squared_error: 0.3192 - val_loss: 0.3749 - val_mean_squared_error: 0.3749
# Epoch 983/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3197 - mean_squared_error: 0.3197 - val_loss: 0.3742 - val_mean_squared_error: 0.3742
# Epoch 984/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3170 - mean_squared_error: 0.3170 - val_loss: 0.3688 - val_mean_squared_error: 0.3688
# Epoch 985/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3157 - mean_squared_error: 0.3157 - val_loss: 0.3521 - val_mean_squared_error: 0.3521
# Epoch 986/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3157 - mean_squared_error: 0.3157 - val_loss: 0.3434 - val_mean_squared_error: 0.3434
# Epoch 987/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3181 - mean_squared_error: 0.3181 - val_loss: 0.3502 - val_mean_squared_error: 0.3502
# Epoch 988/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3325 - mean_squared_error: 0.3325 - val_loss: 0.3869 - val_mean_squared_error: 0.3869
# Epoch 989/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3679 - mean_squared_error: 0.3679 - val_loss: 0.3801 - val_mean_squared_error: 0.3801
# Epoch 990/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3551 - mean_squared_error: 0.3551 - val_loss: 0.3544 - val_mean_squared_error: 0.3544
# Epoch 991/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3347 - mean_squared_error: 0.3347 - val_loss: 0.3487 - val_mean_squared_error: 0.3487
# Epoch 992/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3371 - mean_squared_error: 0.3371 - val_loss: 0.3763 - val_mean_squared_error: 0.3763
# Epoch 993/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3254 - mean_squared_error: 0.3254 - val_loss: 0.3505 - val_mean_squared_error: 0.3505
# Epoch 994/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3224 - mean_squared_error: 0.3224 - val_loss: 0.3515 - val_mean_squared_error: 0.3515
# Epoch 995/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3264 - mean_squared_error: 0.3264 - val_loss: 0.3440 - val_mean_squared_error: 0.3440
# Epoch 996/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3218 - mean_squared_error: 0.3218 - val_loss: 0.3640 - val_mean_squared_error: 0.3640
# Epoch 997/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3198 - mean_squared_error: 0.3198 - val_loss: 0.3753 - val_mean_squared_error: 0.3753
# Epoch 998/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3172 - mean_squared_error: 0.3172 - val_loss: 0.3416 - val_mean_squared_error: 0.3416
# Epoch 999/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3163 - mean_squared_error: 0.3163 - val_loss: 0.3640 - val_mean_squared_error: 0.3640
# Epoch 1000/1000
# 270000/270000 [==============================] - 1s 3us/step - loss: 0.3139 - mean_squared_error: 0.3139 - val_loss: 0.3594 - val_mean_squared_error: 0.3594

# %% [markdown]
# # Plot loss history

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_mean_squared_error', 'loss', 'mean_squared_error'])

# %%
# summarize history for loss
# %matplotlib inline
fig = plt.figure(5, figsize=(8,8))
plt.plot(history.history['loss'], 'b')
plt.plot(history.history['val_loss'], 'r')
plt.yscale('log')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %% [markdown]
# # Evaluate the model

# %%
# On preprocessed data
test_loss, test_mse = model.evaluate(x_test_norm, y_test_norm, verbose=0)
print('MSE for the processed data: %.4f' % (test_mse))
# Out:
# MSE for the processed data: 0.4362

# %%
### Predict real value of points
if norm == 'zero_mean_unit_std_norm':
    predicted_norm_points = model.predict(x_test_norm)
    predicted_points = predicted_norm_points * y_data_stds + y_data_means
    
if norm == 'zero_to_one_norm':
    predicted_norm_points = model.predict(x_test_norm)
    predicted_points = predicted_norm_points * (y_data_max - y_data_min) + y_data_min

# %%
### Get mse for the real predictions
n_points = np.shape(predicted_points)[0]
x_minus_y = predicted_points - y_test

feature_scores = np.sum(np.power(x_minus_y, 2), 0) / n_points
total_score = np.sum(feature_scores) / 2

print('MSE for the unprocessed data: %.4f' % (total_score))
# Out:
# MSE for the unprocessed data: 0.3493

# %% [markdown]
# # Save a model

# %%
### Save the model if it is useful
importlib.reload(model_management)
model_dictionary = {
    'training_method': 'backprop',
    'input_features': input_features,
    'output_features': output_features,
    'number_of_epochs': nEpochs,
    'batch_size': batchSize,
    'number_of_layers': nLayers,
    'neurons_per_layer': neuronsPerLayer,
    'activation_function': activationFunction,
    'train_set_size': train_size,
    'loss_function': loss_function,
    'test_loss': test_loss,
    'test_mse': test_mse,
    'preprocess_data': preprocess_data
}
description = 'First network trained on preprocessed data.'
model_management.SaveModel(model, model_dictionary, description)

# %%
# %matplotlib notebook
#x1 = np.linspace(np.min(x_test[:,0]), np.max(x_test[:,0]), 30)
#x2 = np.linspace(np.min(x_test[:,1]), np.max(x_test[:,1]), 30)
#X1, X2 = np.meshgrid(x1, x2)
#Z = np.zeros(X1.shape)
#for i in range(30):
#    for j in range(30):
#        Z[i, j] = model.predict(np.array([X1[i,j], X2[i,j]])) TODO varför funkar inte det här??
        
#fig = plt.figure(4)
#ax = plt.axes(projection='3d')
#ax.contour3D(X, Y, Z, 50, cmap='binary')
#ax.set_xlabel('x')
#ax.set_ylabel('y')
#ax.set_zlabel('z')
        
### Old visualisation way
### Visualisation of prediction strength for when we have 2 input features
if plot_threeD and len(input_features) == 2:
    predictedY = model.predict(x_test_norm)
    predictedY = predictedY * y_data_stds + y_data_means
    fig = plt.figure(2, figsize=(8,8))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(x_test[:,0], x_test[:,1], 
               y_test[:,0], s=3)
    ax.scatter(x_test[:,0], x_test[:,1], 
               predictedY, s=3)
    ax.set_xlabel('%s log($M_{H}/M_{S}$)' % (input_features[0]))
    ax.set_ylabel('%s log($M_{H}/M_{S}$)' % (input_features[1]))
    ax.set_zlabel('%s log($M_{G}/M_{S}$)' % (output_features[0]))

# %% [markdown]
# # Scatterplots and boxplots

# %%
# %matplotlib inline
#from pylab import plot, show, savefig, xlim, figure, \
#                hold, ylim, legend, boxplot, setp, axes
nBins = 8
bin_edges = np.linspace(halo_min_mass, halo_max_mass, nBins+1)

predictedY = predicted_points

for i, feat in enumerate(output_features):
    
    
    ### Plot 1
    fig = plt.figure(figsize=(8,8))
    
    plt.plot(y_test[:,i], y_test[:,i], 'k.')
    plt.plot(predictedY[:,i], y_test[:,i], 'g.')
    plt.ylabel('True %s %s' % (feat, unit_dict[feat]), fontsize=15)
    plt.xlabel('Predicted %s %s' % (feat, unit_dict[feat]), fontsize=15)
    plt.legend(['Ideal result', 'predicted ' + feat], loc='upper center')
    plt.title('nEpochs: %d, batch size: %d, training set size: %d, test mse score: %.2e\n' % (nEpochs, 
        batchSize, train_size, test_mse) + 
        '%d input feature(s): [%s]\n%d output feature(s): [%s]\n%d test data points (test) shown' % (
        len(input_features), ', '.join(input_features), len(output_features), ', '.join(output_features),
        test_size), y=1.03, fontsize=20)
    plt.show
        
    if save_figs:
        fig.savefig(fig_dir+'bp_output_scatter_%d_plot_from_' % (i+1)+'_and_'.join(input_features)+'_to_'+
            '_and_'.join(output_features)+'_with_'+param_string+'.png', bbox_inches = 'tight')
    
    ### Plot 2 - boxplot
    
    # bin_means contain (0: mean of the binned values, 1: bin edges, 2: numbers pointing each example to a bin)
    bin_means_true = stats.binned_statistic(x_test[:,i], y_test[:,i], bins=bin_edges)
    bin_means_pred = stats.binned_statistic(x_test[:,i], predictedY[:,i].flatten(), bins=bin_edges)
    bin_centers = []
    for iBin in range(nBins):
        bin_center = (bin_means_true[1][iBin] + bin_means_true[1][iBin+1]) / 2
        bin_centers.append('%.2f' % (bin_center))
    sorted_true_y_data = []
    sorted_pred_y_data = []
    for iBin in range(1,nBins+1):
        sorted_true_y_data.append(y_test[bin_means_true[2] == iBin, i])
        sorted_pred_y_data.append(predictedY[bin_means_pred[2] == iBin,i])
        
    fig = plt.figure(figsize=(16,8))
    ax = plt.subplot(111)

    bin_pos = np.array([-2,-1]) # (because this makes it work)
    x_label_centers = []
    for iBin in range(nBins):
        # Every boxplot adds 2 boxes, one from the true data and one from the predicted data
        bin_pos += 3 
        plt.boxplot([sorted_true_y_data[iBin], sorted_pred_y_data[iBin]] , positions = bin_pos, widths = 0.9)
        x_label_centers.append(np.mean(bin_pos))
    
    plt.ylabel('%s %s' % (feat, unit_dict[feat]), fontsize=15)
    plt.xlabel('True Halo mass log($M_{G}/M_{S}$)', fontsize=15)
    ax.set_xlim(left=x_label_centers[0]-2, right=x_label_centers[-1]+2)
    #xlim(0,bin_pos[1] + 1)
    plt.xticks(x_label_centers, bin_centers)
    plt.text(12,7,'Left: true data. Right: predicted data.', fontsize=20)
    
    if feat == 'SFR':
        ax.axhline(y=0, linestyle='--')
    
    plt.title('nEpochs: %d, batch size: %d, training set size: %d, test mse score: %.2e\n' % (nEpochs, 
        batchSize, train_size, test_mse) + 
        '%d input feature(s): [%s]\n%d output feature(s): [%s]\n%d test data points (test) shown' % (
        len(input_features), ', '.join(input_features), len(output_features), ', '.join(output_features),
        test_size), y=1.03, fontsize=20)
    
    plt.show()
    
    if save_figs:
        fig.savefig(fig_dir+'bp_output_boxplot_%d_from_' % (i+1)+'_and_'.join(input_features)+'_to_'+
            '_and_'.join(output_features)+'_with_'+param_string+'.png', bbox_inches = 'tight')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-31-c9fb85c45f11> in <module>()
#      27     if save_figs:
#      28         fig.savefig(fig_dir+'bp_output_scatter_%d_plot_from_' % (i+1)+'_and_'.join(input_features)+'_to_'+
# ---> 29             '_and_'.join(output_features)+'_with_'+param_string+'.png', bbox_inches = 'tight')
#      30
#      31     ### Plot 2 - boxplot
#
# /opt/anaconda/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, **kwargs)
#    1832             self.set_frameon(frameon)
#    1833
# -> 1834         self.canvas.print_figure(fname, **kwargs)
#    1835
#    1836         if frameon:
#
# /opt/anaconda/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2265                 orientation=orientation,
#    2266                 bbox_inches_restore=_bbox_inches_restore,
# -> 2267                 **kwargs)
#    2268         finally:
#    2269             if bbox_inches and restore_bbox:
#
# /opt/anaconda/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     510         renderer.dpi = self.figure.dpi
#     511         if isinstance(filename_or_obj, six.string_types):
# --> 512             filename_or_obj = open(filename_or_obj, 'wb')
#     513             close = True
#     514         else:
#
# OSError: [Errno 36] File name too long: 'figures/bp_output_scatter_1_plot_from_Halo_mass_and_Halo_mass_peak_and_Concentration_and_Type_and_Scale_peak_mass_and_Scale_half_mass_and_Scale_last_MajM_to_Stellar_mass_and_SFR_with_nLayers_20_nNeurons_20_actFun_tanh_lossFunc_mse_nTrainSamples_270000_nEpochs_1000_batchSize_10000.png'

# %% [markdown]
# # Scatterplots and plots with errorbars

# %%
# %matplotlib inline
#from pylab import plot, show, savefig, xlim, figure, \
#                hold, ylim, legend, boxplot, setp, axes
nBins = 8
bin_edges = np.linspace(halo_min_mass, halo_max_mass, nBins+1)

predictedY = predicted_points

for i, feat in enumerate(output_features):
    
    
    ### Plot 1
    fig = plt.figure(figsize=(8,8))
    
    plt.plot(y_test[:,i], y_test[:,i], 'k.')
    plt.plot(predictedY[:,i], y_test[:,i], 'g.')
    plt.ylabel('True %s %s' % (feat, unit_dict[feat]), fontsize=15)
    plt.xlabel('Predicted %s %s' % (feat, unit_dict[feat]), fontsize=15)
    plt.legend(['Ideal result', 'predicted ' + feat], loc='upper center')
    plt.title('nEpochs: %d, batch size: %d, training set size: %d, test mse score: %.2e\n' % (nEpochs, 
        batchSize, train_size, test_mse) + 'loss function: %s\n' % (loss_function) +
        '%d input feature(s): [%s]\n%d output feature(s): [%s]\n%d data points (test) shown' % (
        len(input_features), ', '.join(input_features), len(output_features), ', '.join(output_features),
        test_size), y=1.03, fontsize=20)
    plt.show
        
    if save_figs:
        fig.savefig(fig_dir+'bp_output_scatter_%d_plot_from_' % (i+1)+'_and_'.join(input_features)+'_to_'+
            '_and_'.join(output_features)+'_with_'+param_string+'.png', bbox_inches = 'tight')
    
    ### Plot 2 - boxplot
    
    # bin_means contain (0: mean of the binned values, 1: bin edges, 2: numbers pointing each example to a bin)
    bin_means_true = stats.binned_statistic(x_test[:,i], y_test[:,i], bins=bin_edges)
    bin_means_pred = stats.binned_statistic(x_test[:,i], predictedY[:,i].flatten(), bins=bin_edges)
    bin_centers = []
    for iBin in range(nBins):
        bin_center = (bin_means_true[1][iBin] + bin_means_true[1][iBin+1]) / 2
        bin_centers.append('%.2f' % (bin_center))
    sorted_true_y_data = []
    sorted_pred_y_data = []
    for iBin in range(1,nBins+1):
        sorted_true_y_data.append(y_test[bin_means_true[2] == iBin, i])
        sorted_pred_y_data.append(predictedY[bin_means_pred[2] == iBin,i])
    
    # get standard deviations of the binned values
    stds_true = np.zeros((nBins))
    stds_pred = np.zeros((nBins))
    for iBin in range(nBins):
        stds_true[iBin] = np.std(sorted_true_y_data[iBin])
        stds_pred[iBin] = np.std(sorted_pred_y_data[iBin])
        
    fig = plt.figure(figsize=(16,8))
    ax = plt.subplot(111)

    bin_pos = np.array([-2,-1]) # (because this makes it work)
    x_label_centers = []
    for iBin in range(nBins):
        # Every plot adds 2 distributions, one from the true data and one from the predicted data
        bin_pos += 3 
        plt.errorbar(bin_pos[0], bin_means_true[0][iBin], yerr=stds_true[iBin], fmt = 'bo', capsize=5)
        plt.errorbar(bin_pos[1], bin_means_pred[0][iBin], yerr=stds_pred[iBin], fmt = 'ro', capsize=5)
        x_label_centers.append(np.mean(bin_pos))
    
    plt.ylabel('%s %s' % (feat, unit_dict[feat]), fontsize=15)
    plt.xlabel('True Halo mass log($M_{G}/M_{S}$)', fontsize=15)
    plt.legend(['True data $\pm 1 \sigma$', 'Predicted data $\pm 1 \sigma$'], loc='upper left', fontsize='xx-large')
    ax.set_xlim(left=x_label_centers[0]-2, right=x_label_centers[-1]+2)
    #xlim(0,bin_pos[1] + 1)
    plt.xticks(x_label_centers, bin_centers)
    
    plt.title('nEpochs: %d, batch size: %d, training set size: %d, test mse score: %.2e\n' % (nEpochs, 
        batchSize, train_size, test_mse) + 'loss function: %s\n' % (loss_function) +
        '%d input feature(s): [%s]\n%d output feature(s): [%s]\n%d data points (test) shown' % (
        len(input_features), ', '.join(input_features), len(output_features), ', '.join(output_features),
        test_size), y=1.03, fontsize=20)
    
    plt.show()
    
    if save_figs:
        fig.savefig(fig_dir+'bp_output_boxplot_%d_from_' % (i+1)+'_and_'.join(input_features)+'_to_'+
            '_and_'.join(output_features)+'_with_'+param_string+'.png', bbox_inches = 'tight')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-32-8460434c27ae> in <module>()
#      27     if save_figs:
#      28         fig.savefig(fig_dir+'bp_output_scatter_%d_plot_from_' % (i+1)+'_and_'.join(input_features)+'_to_'+
# ---> 29             '_and_'.join(output_features)+'_with_'+param_string+'.png', bbox_inches = 'tight')
#      30
#      31     ### Plot 2 - boxplot
#
# /opt/anaconda/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, **kwargs)
#    1832             self.set_frameon(frameon)
#    1833
# -> 1834         self.canvas.print_figure(fname, **kwargs)
#    1835
#    1836         if frameon:
#
# /opt/anaconda/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2265                 orientation=orientation,
#    2266                 bbox_inches_restore=_bbox_inches_restore,
# -> 2267                 **kwargs)
#    2268         finally:
#    2269             if bbox_inches and restore_bbox:
#
# /opt/anaconda/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     510         renderer.dpi = self.figure.dpi
#     511         if isinstance(filename_or_obj, six.string_types):
# --> 512             filename_or_obj = open(filename_or_obj, 'wb')
#     513             close = True
#     514         else:
#
# OSError: [Errno 36] File name too long: 'figures/bp_output_scatter_1_plot_from_Halo_mass_and_Halo_mass_peak_and_Concentration_and_Type_and_Scale_peak_mass_and_Scale_half_mass_and_Scale_last_MajM_to_Stellar_mass_and_SFR_with_nLayers_20_nNeurons_20_actFun_tanh_lossFunc_mse_nTrainSamples_270000_nEpochs_1000_batchSize_10000.png'

# %%
#print(predictedY.flatten())
#bin_means = stats.binned_statistic(predictedY.flatten(), y_test[:,0], bins=10)
#bin_stds = stats.binned_statistic(predictedY.flatten(), y_test[:,0], bins=10, statistic=GetSTD)
#print(bin_means[0])
#print(bin_stds[0])

# %% [markdown]
# # Plot SFR vs Stellar mass

# %%
predictedY = model.predict(x_test_norm)
predictedY = predictedY * y_data_stds + y_data_means

fig = plt.figure(figsize=(12,8))
ax = plt.subplot(121)

plt.plot(predictedY[:,0], predictedY[:,1], 'b.', markersize=2)
plt.ylabel('Predicted SFR %s' % (unit_dict['SFR']), fontsize=15)
plt.xlabel('Predicted Stellar Mass %s' % (unit_dict['Stellar_mass']), fontsize=15)
ymin, ymax = ax.get_ylim()
ax.set_ylim(bottom=ymin, top=ymax)

ax = plt.subplot(122)
plt.plot(y_test[:,0], y_test[:,1], 'k.', markersize=2)
plt.ylabel('True SFR %s' % (unit_dict['SFR']), fontsize=15)
plt.xlabel('True Stellar Mass %s' % (unit_dict['Stellar_mass']), fontsize=15)
ax.set_ylim(bottom=ymin, top=ymax)
plt.suptitle('nEpochs: %d, batch size: %d, training set size: %d, test mse score: %.2e\n' % (nEpochs, 
    batchSize, train_size, total_score) + 'loss function: %s\n' % (loss_function) +
    '%d input feature(s): [%s]\n%d output feature(s): [%s]\n%d data points (test) shown' % (
    len(input_features), ', '.join(input_features), len(output_features), ', '.join(output_features),
    test_size), y=1.17, fontsize=20)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
### Save the figure
fig.savefig(fig_dir+'bp_sfr_to_stellar_mass_inputs_' + '_and_'.join(input_features)+
            '_with_'+param_string+'.png', bbox_inches = 'tight')

# %% [markdown]
# # Plot loss history

# %%
# list all data in history
print(history.history.keys())

# %%
# summarize history for loss
# %matplotlib inline
fig = plt.figure(5, figsize=(8,8))
plt.plot(history.history['loss'], 'b')
plt.plot(history.history['val_loss'], 'r')
plt.yscale('log')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %% [markdown]
# # Check to see how the MSE is calculated

# %%
predicted_points = model.predict(x_test)
print(np.shape(predicted_points))
n_points = np.shape(predicted_points)[0]
x_minus_y = predicted_points - y_test

feature_scores = np.sum(np.power(x_minus_y, 2), 0) / n_points
total_score = np.sum(feature_scores) / 2

print(total_score)

keras_scores = model.evaluate(x_test, y_test, verbose=0)
print(keras_scores)

# %%
# summarize history for loss
# %matplotlib inline
fig = plt.figure(5, figsize=(8,8))
plt.plot(history.history['loss'], 'b')
plt.plot(history.history['val_loss'], 'r')
plt.yscale('log')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %% [markdown]
# # Plot loss history

# %%
# list all data in history
print(history.history.keys())

# %%
# summarize history for loss
# %matplotlib inline
fig = plt.figure(5, figsize=(8,8))
plt.plot(history.history['loss'], 'b')
plt.plot(history.history['val_loss'], 'r')
plt.yscale('log')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %% [markdown]
# # Plot loss history

# %%
# list all data in history
print(history.history.keys())
